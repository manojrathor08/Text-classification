# %%
# data analysis
import numpy as np
import pandas as pd

# %%
# data visulaization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/manoj/Desktop/assignment/Consumer_Complaints.csv')
#df.info()
#df.head()

# %%
df = df.drop(['Date received'],axis =1)
df = df.drop(['Complaint ID'],axis =1)
df = df.drop(['State'],axis =1)
df = df.drop(['Consumer consent provided?'],axis =1)
df = df.drop(['ZIP code'],axis =1)
df = df.drop(['Date sent to company'],axis =1)
df = df.drop(['Tags'],axis =1)
#df = df.drop([''],axis =1)
#df = df.drop([''],axis =1)
#df = df.drop([''],axis =1)
#df = df.drop([''],axis =1)

# %%
df.describe(include ='all')
# Out:
#          Product       Sub-product                                     Issue  \
# count    1131011            895843                                   1131011
# unique        18                76                                       166
# top     Mortgage  Credit reporting  Loan modification,collection,foreclosure
# freq      264785            152649                                    112313
#
#              Sub-issue                       Consumer complaint narrative  \
# count           619937                                             326489
# unique             218                                             314043
# top     Account status  There are many mistakes appear in my report wi...
# freq             37057                                                530
#
#                                   Company public response        Company  \
# count                                              372501        1131011
# ...

# %%
df['Timely response?']= df['Timely response?'].map({'Yes':1,'No':0})
df['Consumer disputed?']= df['Consumer disputed?'].map({'Yes':1,'No':0})

# %%
df.describe(include= 'all')
# Out:
#          Product       Sub-product                                     Issue  \
# count    1131011            895843                                   1131011
# unique        18                76                                       166
# top     Mortgage  Credit reporting  Loan modification,collection,foreclosure
# freq      264785            152649                                    112313
# mean         NaN               NaN                                       NaN
# std          NaN               NaN                                       NaN
# min          NaN               NaN                                       NaN
# 25%          NaN               NaN                                       NaN
# 50%          NaN               NaN                                       NaN
# 75%          NaN               NaN                                       NaN
# max          NaN               NaN                                       NaN
#
# ...

# %%
df.groupby('Submitted via').groups
# Out:
# {'Email': Int64Index([   170,   2148,   2623,   2763,   5809,   6849,   8781,  10138,
#               10277,  11565,
#              ...
#              917802, 918900, 919481, 923507, 926546, 926948, 927564, 927747,
#              930500, 935278],
#             dtype='int64', length=372),
#  'Fax': Int64Index([     15,      64,      92,     174,     237,     240,     250,
#                  265,     307,     310,
#              ...
#               975205,  981863, 1031439, 1063400, 1073584, 1076737, 1081341,
#              1086709, 1099536, 1128513],
#             dtype='int64', length=17647),
#  'Phone': Int64Index([      5,      19,      52,      98,     114,     122,     127,
#                  132,     158,     161,
#              ...
#              1087314, 1091523, 1092514, 1098411, 1100159, 1102540, 1104596,
#              1105701, 1114102, 1130670],
#             dtype='int64', length=68379),
# ...

# %%
df[["Issue", "Timely response?"]].groupby(['Issue'], as_index=False).mean().sort_values(by='Timely response?', ascending=False)
# Out:
#                                                  Issue  Timely response?
# 80                 Lender damaged or destroyed vehicle          1.000000
# 130         Property was damaged or destroyed property          1.000000
# 160       Vehicle was damaged or destroyed the vehicle          1.000000
# 121                          Problem with cash advance          1.000000
# 40                                  Convenience checks          1.000000
# 7                Advertising, marketing or disclosures          1.000000
# 44                                Credit limit changed          1.000000
# 125                             Problem with overdraft          1.000000
# 105            Overdraft, savings, or rewards features          1.000000
# 152           Unable to get credit report/credit score          0.998895
# 49            Credit reporting company's investigation          0.998815
# 46            Credit monitoring or identity protection          0.998192
# ...

# %%
df.head()
# Out:
#                        Product                                 Sub-product  \
# 0                     Mortgage                              Other mortgage
# 1                 Student loan              Federal student loan servicing
# 2  Credit card or prepaid card  General-purpose credit card or charge card
# 3                  Credit card                                         NaN
# 4              Debt collection                                 Credit card
#
#                                       Issue  \
# 0  Loan modification,collection,foreclosure
# 1        Dealing with my lender or servicer
# 2        Other features, terms, or problems
# 3                                Bankruptcy
# 4                     Communication tactics
#
#                                 Sub-issue  \
# 0                                     NaN
# 1  Received bad information about my loan
# 2                           Other problem
# 3                                     NaN
# ...

# %%
# drop those rows which contain null values
df = df.dropna()

# %%
df.head()
# Out:
#       Date received          Product                            Sub-product  \
# 953      10/20/2015  Debt collection                               Mortgage
# 2417     12/01/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 3589     03/21/2017  Debt collection  Other (i.e. phone, health club, etc.)
# 8667     03/01/2016  Debt collection  Other (i.e. phone, health club, etc.)
# 13523    06/01/2016  Debt collection  Other (i.e. phone, health club, etc.)
#
#                                        Issue  \
# 953    Cont'd attempts collect debt not owed
# 2417    Taking/threatening an illegal action
# 3589   Cont'd attempts collect debt not owed
# 8667   Cont'd attempts collect debt not owed
# 13523  Cont'd attempts collect debt not owed
#
#                                  Sub-issue  \
# 953                          Debt was paid
# 2417   Attempted to/Collected exempt funds
# 3589                      Debt is not mine
# 8667     Debt resulted from identity theft
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2409 entries, 953 to 1130969
# Data columns (total 18 columns):
# Date received                   2409 non-null object
# Product                         2409 non-null object
# Sub-product                     2409 non-null object
# Issue                           2409 non-null object
# Sub-issue                       2409 non-null object
# Consumer complaint narrative    2409 non-null object
# Company public response         2409 non-null object
# Company                         2409 non-null object
# State                           2409 non-null object
# ZIP code                        2409 non-null object
# Tags                            2409 non-null object
# Consumer consent provided?      2409 non-null object
# Submitted via                   2409 non-null object
# Date sent to company            2409 non-null object
# Company response to consumer    2409 non-null object
# Timely response?                2409 non-null object
# ...

# %%
df.describe(include = 'all')
# Out:
#                 Product                            Sub-product  \
# count              3129                                   3129
# unique                2                                     10
# top     Debt collection  Other (i.e. phone, health club, etc.)
# freq               2992                                   1086
#
#                                         Issue         Sub-issue  \
# count                                    3129              3129
# unique                                      9                37
# top     Cont'd attempts collect debt not owed  Debt is not mine
# freq                                     1475               888
#
#                              Consumer complaint narrative  \
# count                                                3129
# unique                                               3111
# top     Reporting erroneously/ incorrectly/ inaccurate...
# freq                                                    3
#
# ...
